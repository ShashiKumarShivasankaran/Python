# %%
import pandas as pd

# %% [markdown]
# # ------------------------------------------ Cereals --------------------------------------------------------

# %%
cereals = pd.read_csv('cereals_data.csv')
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 1. Add index name fast on name

# %% [markdown]
# #### 2. Describe the schema of table

# %%
cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    75 non-null     float64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(7), int64(6), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# #### 3. Create view name as see where users can not see type column [first run appropriate query then create view]

# %%
cereals.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
cereals.copy(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
       'rating'],
      dtype='object')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cereals.copy(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#       2        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#       3        'rating'],
#       4       dtype='object')
#
# TypeError: NDFrame.copy() got an unexpected keyword argument 'dtype'

# %% [markdown]
# #### 4. Rename the view as saw

# %%
df_cereals = cereals.copy(deep=True)

# %% [markdown]
# #### 5. Count how many are cold cereals

# %%
cereals[cereals.type == 'C'].shape[0]       # both are good to use
len(cereals[cereals.type == 'C'])
# Out:
# 74

# %% [markdown]
# #### 6. Count how many cereals are kept in shelf 3

# %%
cereals[cereals.shelf == 3].shape[0]
# Out:
# 36

# %% [markdown]
# #### 7. Arrange the table from high to low according to ratings

# %%
cereals.sort_values('rating',ascending=False)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 64     Shredded_Wheat_'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded_Wheat_spoon_size   N    C        90        3    0       0    3.0
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 63             Shredded_Wheat   N    C        80        2    0       0    3.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 14                Cocoa_Puffs   G    C       110        1    1     180    0.0
# 18              Count_Chocula   G    C       110        1    1     180    0.0
# 35           Honey_Graham_Ohs   Q    C       120        1    2     220    1.0
# 12      Cinnamon_Toast_Crunch   G    C       120        1    3     210    0.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
#
# ...

# %% [markdown]
# #### 8. Suggest some column/s which can be Primary key

# %%
cereals.shape
# Out:
# (77, 16)

# %%
cereals.name.nunique()
# Out:
# 77

# %%
cereals.name.isnull().sum()
# Out:
# 0

# %%
cereals.reset_index()
# Out:
#     index                       name mfr type  calories  protein  fat  sodium  \
# 0       0                  100%_Bran   N    C        70        4    1     130
# 1       1          100%_Natural_Bran   Q    C       120        3    5      15
# 2       2                   All-Bran   K    C        70        4    1     260
# 3       3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140
# 4       4             Almond_Delight   R    C       110        2    2     200
# ..    ...                        ...  ..  ...       ...      ...  ...     ...
# 72     72                    Triples   G    C       110        2    1     250
# 73     73                       Trix   G    C       110        1    1     140
# 74     74                 Wheat_Chex   R    C       100        3    1     230
# 75     75                   Wheaties   G    C       100        3    1     200
# 76     76        Wheaties_Honey_Gold   G    C       110        2    1     200
#
# ...

# %%
cereals.rename(columns = {'index':'Primary key'},inplace=True)
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 9. Find average of calories of hot cereal and cold cereal in one query

# %%
cereals.groupby('type')['calories'].mean()
# Out:
# type
# C    107.162162
# H    100.000000
# Name: calories, dtype: float64

# %% [markdown]
# #### 10. Add new column as HL_Calories where more than average calories should be categorized as HIGH and less than average calories should be categorized as LOW

# %%
cereals['HL_Calories'] = cereals.calories.apply( lambda x:'Low' if x < df_cereals['calories'].mean() else 'High')
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 11. List only those cereals whose name begins with B

# %%
cereals[cereals.name.str.lower().str.startswith('B')]
# Out:
#           name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 7      Basic_4   G    C       130        3    2     210    2.0   18.0     8.0
# 8    Bran_Chex   R    C        90        2    1     200    4.0   15.0     6.0
# 9  Bran_Flakes   P    C        90        3    0     210    5.0   13.0     5.0
#
#    potass  vitamins  shelf  weight  cups     rating HL_Calories
# 7   100.0        25      3    1.33  0.75  37.038562        High
# 8   125.0        25      1    1.00  0.67  49.120253         Low
# 9   190.0        25      3    1.00  0.67  53.313813         Low

# %% [markdown]
# #### 12. List only those cereals whose name begins with F

# %%
cereals[cereals.name.str.startswith('F')]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 24                             Froot_Loops   K    C       110        2    1
# 25                          Frosted_Flakes   K    C       110        1    0
# 26                     Frosted_Mini-Wheats   K    C       100        3    0
# 27  Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   P    C       120        3    2
# 28                           Fruitful_Bran   K    C       120        3    0
# 29                          Fruity_Pebbles   P    C       110        1    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 24     125    1.0   11.0    13.0    30.0        25      2    1.00  1.00
# 25     200    1.0   14.0    11.0    25.0        25      1    1.00  0.75
# 26       0    3.0   14.0     7.0   100.0        25      2    1.00  0.80
# 27     160    5.0   12.0    10.0   200.0        25      3    1.25  0.67
# 28     240    5.0   14.0    12.0   190.0        25      3    1.33  0.67
# ...

# %% [markdown]
# #### 13. List only those cereals whose name ends with s

# %%
cereals[cereals.name.str.lower().str.endswith('s')]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 5                  Apple_Cinnamon_Cheerios   G    C       110        2    2
# 6                              Apple_Jacks   K    C       110        2    0
# 9                              Bran_Flakes   P    C        90        3    0
# 11                                Cheerios   G    C       110        6    2
# 13                                Clusters   G    C       110        3    2
# 14                             Cocoa_Puffs   G    C       110        1    1
# 16                             Corn_Flakes   K    C       100        2    0
# 17                               Corn_Pops   K    C       110        1    0
# 22                  Crispy_Wheat_&_Raisins   G    C       100        2    1
# 24                             Froot_Loops   K    C       110        2    1
# 25                          Frosted_Flakes   K    C       110        1    0
# ...

# %% [markdown]
# #### 14. Select only those records which are HIGH in column HL_calories

# %%
high_calories = cereals[cereals.HL_Calories == 'High']

# %%
high_calories.to_csv('Assignment_of_high_calories.csv')

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\PGDA\\Python\\1. Data Manipulation using Pandas'

# %% [markdown]
# #### 15. Find maximum of ratings

# %%
cereals.rating.max()
# Out:
# 93.704912

# %% [markdown]
# #### 16. Find average ratings of those were High and Low calories

# %%
cereals.groupby('HL_Calories')['rating'].mean()
# Out:
# HL_Calories
# High    34.919791
# Low     54.800971
# Name: rating, dtype: float64

# %% [markdown]
# #### 17. Create two examples of Sub Queries of your choice and give explanation in the script itself with remarks by using
#
# #### Find all the information whose rating is less than the All-Bran ratings

# %%
cereals[cereals.name == 'All-Bran']['rating'].values[0]
# Out:
# 59.425505

# %%
cereals[cereals.rating < cereals[cereals.name == 'All-Bran']['rating'].values[0]]
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 1         100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 4            Almond_Delight   R    C       110        2    2     200    1.0
# 5   Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# 6               Apple_Jacks   K    C       110        2    0     125    1.0
# 7                   Basic_4   G    C       130        3    2     210    2.0
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat_Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 18. Remove column fat

# %%
cereals.drop('fat',axis=1)
# Out:
#                          name mfr type  calories  protein  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3      15    2.0
# 2                    All-Bran   K    C        70        4     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4     140   14.0
# 4              Almond_Delight   R    C       110        2     200    1.0
# ..                        ...  ..  ...       ...      ...     ...    ...
# 72                    Triples   G    C       110        2     250    0.0
# 73                       Trix   G    C       110        1     140    0.0
# 74                 Wheat_Chex   R    C       100        3     230    3.0
# 75                   Wheaties   G    C       100        3     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# ...

# %% [markdown]
# #### 19. Count records for each manufacturer [mfr]

# %%
cereals.mfr.value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %% [markdown]
# #### 20. Select name, calories and ratings only

# %%
cereals[['name','calories','rating']]
# Out:
#                          name  calories     rating
# 0                   100%_Bran        70  68.402973
# 1           100%_Natural_Bran       120  33.983679
# 2                    All-Bran        70  59.425505
# 3   All-Bran_with_Extra_Fiber        50  93.704912
# 4              Almond_Delight       110  34.384843
# ..                        ...       ...        ...
# 72                    Triples       110  39.106174
# 73                       Trix       110  27.753301
# 74                 Wheat_Chex       100  49.787445
# 75                   Wheaties       100  51.592193
# 76        Wheaties_Honey_Gold       110  36.187559
#
# [77 rows x 3 columns]

# %%
cereals.sample(frac = 0.2, random_state = 1)
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 31        Golden_Grahams   G    C       110        1    1     280    0.0
# 43                 Maypo   A    H       100        4    1       0    0.0
# 26   Frosted_Mini-Wheats   K    C       100        3    0       0    3.0
# 74            Wheat_Chex   R    C       100        3    1     230    3.0
# 58           Raisin_Bran   K    C       120        3    1     210    5.0
# 59       Raisin_Nut_Bran   G    C       100        3    2     140    2.5
# 61             Rice_Chex   R    C       110        1    0     240    0.0
# 51  Oatmeal_Raisin_Crisp   G    C       130        3    2     170    1.5
# 36    Honey_Nut_Cheerios   G    C       110        3    1     250    1.5
# 57        Quaker_Oatmeal   Q    H       100        5    2       0    2.7
# 10          Cap'n'Crunch   Q    C       120        1    2     220    0.0
# 53            Product_19   K    C       100        3    0     320    1.0
# ...

# %%
cereals.fat.apply(lambda x: 'zero' if x == 0 else('one' if x == 1 else('two' if x == 2 else('three' if x == 3 else x))))
# Out:
# 0      one
# 1        5
# 2      one
# 3     zero
# 4      two
#       ...
# 72     one
# 73     one
# 74     one
# 75     one
# 76     one
# Name: fat, Length: 77, dtype: object

# %%
cereals.fat.replace({0:'zero',1:'one',2:'two'})
# Out:
# 0      one
# 1        5
# 2      one
# 3     zero
# 4      two
#       ...
# 72     one
# 73     one
# 74     one
# 75     one
# 76     one
# Name: fat, Length: 77, dtype: object

# %% [markdown]
# change mfr 'K' for crispix

# %%
cereals[cereals == 'crispix']
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating, HL_Calories]
# Index: []

# %%
cereals.loc[21, 'mfr'] = 'M'
cereals.iloc[21]
# Out:
# name             Crispix
# mfr                    M
# type                   C
# calories             110
# protein                2
# fat                    0
# sodium               220
# fiber                1.0
# carbo               21.0
# sugars               3.0
# potass              30.0
# vitamins              25
# shelf                  3
# weight               1.0
# cups                 1.0
# rating         46.895644
# HL_Calories         High
# Name: 21, dtype: object

# %%
cereals.loc[cereals['name'] == 'Maypo','mfr'] = 'S'

# %%
cereals.iloc[43]
# Out:
# name               Maypo
# mfr                    S
# type                   H
# calories             100
# protein                4
# fat                    1
# sodium                 0
# fiber                0.0
# carbo               16.0
# sugars               3.0
# potass              95.0
# vitamins              25
# shelf                  2
# weight               1.0
# cups                 1.0
# rating         54.850917
# HL_Calories          Low
# Name: 43, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Q1 = cereals.rating.quantile(.25)
Q3 = cereals.rating.quantile(.75)

IQR = Q3 - Q1                                   # IQR means 50% of data

HE = Q3 + 1.5*IQR
LE = Q1 - 1.5*IQR

# %%
Q1
# Out:
# 33.174094

# %%
Q3
# Out:
# 50.828392

# %%
HE
# Out:
# 77.30983900000001

# %%
LE
# Out:
# 6.69264699999999

# %%
cereals.rating.mean()
# Out:
# 42.66570498701299

# %%
plt.boxplot(cereals.rating)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ff2b5646d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ff2b418d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ff2b566850>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ff2b56a5d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ff2b59afd0>],
#  'means': []}

# %% [markdown]
# # ------------------------------------------ End of Cereals ----------------------------------------------
